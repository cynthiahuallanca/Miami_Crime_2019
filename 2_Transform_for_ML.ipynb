# %%
import pandas as pd
# import matplotlib.pylab as plt
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline
import numpy as np

# %%
df = pd.read_csv('Resources/data1_extract_clean.csv')
df.head()
# Out:
#    Unnamed: 0                  Defendant            Address  Zip      City  \
# 0           5              AMADOR, PEDRO            UNKNOWN  NaN     MIAMI
# 1           6              ANDREW, GRACE            UNKNOWN  NaN     MIAMI
# 2          21          BRADLEY, HENRY  L   15821 NW 28TH PL  NaN     MIAMI
# 3          22              BRANDT, JAMES           HOMELESS  NaN  HOMELESS
# 4          36  DANIELS, DORIAN  LAFRANCE  157 NE 67TH ST  2  NaN     MIAMI
#
#   State  Booking_month Booking_Date Booking_year_month  DOB_month  \
# 0    FL              5   2015-05-29            2015-05         10
# 1    FL              5   2015-05-29            2015-05          9
# 2    FL              5   2015-05-29            2015-05          8
# 3    FL              5   2015-05-29            2015-05          4
# 4    FL              5   2015-05-29            2015-05          8
#
#   Date_of_birth  Age day_of_week                        Crime_Family  \
# 0    1996-10-12   22      Friday  THEFT, ROBBERY, AND RELATED CRIMES
# 1    1963-09-26   55      Friday  THEFT, ROBBERY, AND RELATED CRIMES
# 2    1986-08-21   32      Friday               BURGLARY AND TRESPASS
# 3    1972-04-11   47      Friday   DRUG ABUSE PREVENTION AND CONTROL
# 4    1988-08-29   30      Friday                             WARRANT
#
#           Crime_Family1    Crime_Family2    CityRN
# 0     ASSAULT & BATTERY   PERSONAL CRIME     MIAMI
# 1     ASSAULT & BATTERY   PERSONAL CRIME     MIAMI
# 2              BURGLARY   PERSONAL CRIME     MIAMI
# 3       DRUGS & ALCOHOL  STATUTORY CRIME  HOMELESS
# 4  MISCELLANEOUS CRIMES            OTHER     MIAMI

# %% [markdown]
# ### Categories for Machine Learning Model

# %%
# Create a new column for Age categories with ranges: 0-25 , 26-50 , >50 where the value is 1 if it is true and 0 if not
df['Age<25'] = np.where(df['Age']<=25, 1,0)
df['Age26-50'] = np.where((df['Age']>25) & (df['Age']<=50), 1,0)
df['Age>50'] = np.where(df['Age']>50, 1,0)

# df.head()

# %%
df['Booking_month'] = df['Booking_month'].astype(int)

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# Defendant              object
# Address                object
# Zip                   float64
# City                   object
# State                  object
# Booking_month           int32
# Booking_Date           object
# Booking_year_month     object
# DOB_month               int64
# Date_of_birth          object
# Age                     int64
# day_of_week            object
# Crime_Family           object
# Crime_Family1          object
# Crime_Family2          object
# CityRN                 object
# Age<25                  int32
# Age26-50                int32
# Age>50                  int32
# dtype: object

# %%
# Create Seasons columns where: Summer= 7, 8, 9. Spring=4,5,6. Winter=1,2,3. Autum=10,11,12.
df['Summer'] = np.where((df['Booking_month']>=7) & (df['Booking_month']<=9), 1,0)
df['Spring'] = np.where((df['Booking_month']>=4) & (df['Booking_month']<=6), 1,0)
df['Winter'] = np.where((df['Booking_month']>=1) & (df['Booking_month']<=3), 1,0)
df['Autum'] = np.where((df['Booking_month']>=10) & (df['Booking_month']<=12), 1,0)

# %%
df.tail()
# Out:
#        Unnamed: 0                     Defendant          Address      Zip  \
# 31250      229305                  DAVIS, RICKY          UNKNOWN      NaN
# 31251      229310  DUNCOMBE, TAMYIAH  DOMONIQUE   1180 SW 26 AVE  33312.0
# 31252      229311        DUNLAP, WILLIE  CURTIS         HOMELESS      NaN
# 31253      229313       EDMONDS, LATHERN  DAVID         HOMELESS      NaN
# 31254      229314               ELKABBAJ, HAMZA  ADDRESS UNKNOWN      NaN
#
#                   City State  Booking_month Booking_Date Booking_year_month  \
# 31250            MIAMI    FL              6   2019-06-13            2019-06
# 31251  FORT LAUDERDALE    FL              6   2019-06-13            2019-06
# 31252         HOMELESS    FL              6   2019-06-13            2019-06
# 31253         HOMELESS    FL              6   2019-06-13            2019-06
# 31254            MIAMI    FL              6   2019-06-13            2019-06
#
#        DOB_month  ...           Crime_Family1   Crime_Family2    CityRN  \
# 31250          4  ...    MISCELLANEOUS CRIMES           OTHER     MIAMI
# 31251         12  ...    MISCELLANEOUS CRIMES           OTHER   FOREIGN
# 31252          1  ...    MISCELLANEOUS CRIMES           OTHER  HOMELESS
# 31253          6  ...       SEXUAL MISCONDUCT  PERSONAL CRIME  HOMELESS
# 31254          6  ...                BURGLARY  PERSONAL CRIME     MIAMI
#
#       Age<25 Age26-50 Age>50 Summer  Spring  Winter  Autum
# 31250      0        1      0      0       1       0      0
# 31251      1        0      0      0       1       0      0
# 31252      0        1      0      0       1       0      0
# 31253      0        1      0      0       1       0      0
# 31254      0        1      0      0       1       0      0
#
# [5 rows x 24 columns]

# %%
# Drop innecesary columns
df.drop(['Unnamed: 0','Address','City','State','Crime_Family2','Crime_Family'], axis=1, inplace=True)

# %%
df["total_crime"] = df['Age<25'] + df['Age26-50'] + df['Age>50']
# df.head()

# %%
# Filter by State of Florida only (dropping NA also)  
df_assault = df.loc[df['Crime_Family1'] == "ASSAULT & BATTERY",:]
# df_assault.head()

# %%
df.count()
# Out:
# Defendant             31255
# Zip                    4881
# Booking_month         31255
# Booking_Date          31255
# Booking_year_month    31255
# DOB_month             31255
# Date_of_birth         31255
# Age                   31255
# day_of_week           31255
# Crime_Family1         31255
# CityRN                31255
# Age<25                31255
# Age26-50              31255
# Age>50                31255
# Summer                31255
# Spring                31255
# Winter                31255
# Autum                 31255
# total_crime           31255
# dtype: int64

# %%
df_assault_drop = df_assault.copy()

# %%
# Drop innecesary columns
df_assault_drop.drop(['Defendant','Zip','Booking_Date','Date_of_birth','Crime_Family1','Booking_year_month','Booking_month','Age'], axis=1, inplace=True)

# %%
# df_assault_drop.to_csv("Resources/df_assault_drop.csv",index=True,header=True)

# %%
df_assault_drop.head()
# Out:
#     DOB_month day_of_week    CityRN  Age<25  Age26-50  Age>50  Summer  Spring  \
# 0          10      Friday     MIAMI       1         0       0       0       1
# 1           9      Friday     MIAMI       0         0       1       0       1
# 9           8    Saturday  HOMELESS       0         1       0       0       1
# 10          3    Saturday     MIAMI       0         1       0       0       1
# 14         10    Saturday  HOMELESS       0         1       0       0       1
#
#     Winter  Autum  total_crime
# 0        0      0            1
# 1        0      0            1
# 9        0      0            1
# 10       0      0            1
# 14       0      0            1

# %%
# Create Columns for Days of the week and other categories, in order to apply machine learning model after
df_dummies = pd.get_dummies(df_assault_drop)
# df_dummies.head()

# %%
# df_dummies.to_csv("Resources/df_dummies.csv",index=True,header=True)

# %%
df_combined = df_assault.copy()

# %%
# Create df to prepare data for ML
df_combined['day_of_week_Monday'] = df_dummies['day_of_week_Monday']
df_combined['day_of_week_Tuesday'] = df_dummies['day_of_week_Tuesday']
df_combined['day_of_week_Wednesday'] = df_dummies['day_of_week_Wednesday']
df_combined['day_of_week_Thursday'] = df_dummies['day_of_week_Thursday']
df_combined['day_of_week_Friday'] = df_dummies['day_of_week_Friday']
df_combined['day_of_week_Saturday'] = df_dummies['day_of_week_Saturday']
df_combined['day_of_week_Sunday'] = df_dummies['day_of_week_Sunday']
df_combined['CityRN_FOREIGN'] = df_dummies['CityRN_FOREIGN']
df_combined['CityRN_HOMELESS'] = df_dummies['CityRN_HOMELESS']
df_combined['CityRN_MIAMI'] = df_dummies['CityRN_MIAMI']

# %%
# df_combined.head()

# %%
# df_combined.to_csv("Resources/df_combined.csv",index=True,header=True)

# %%
# Drop innecesary columns
df_combined.drop(['Defendant','Zip','Booking_Date','Date_of_birth','Age','day_of_week','Crime_Family1','CityRN'], axis=1, inplace=True)

# %%
df_combined.head()
# Out:
#     Booking_month Booking_year_month  DOB_month  Age<25  Age26-50  Age>50  \
# 0               5            2015-05         10       1         0       0
# 1               5            2015-05          9       0         0       1
# 9               5            2015-05          8       0         1       0
# 10              5            2015-05          3       0         1       0
# 14              5            2015-05         10       0         1       0
#
#     Summer  Spring  Winter  Autum      ...       day_of_week_Monday  \
# 0        0       1       0      0      ...                        0
# 1        0       1       0      0      ...                        0
# 9        0       1       0      0      ...                        0
# 10       0       1       0      0      ...                        0
# 14       0       1       0      0      ...                        0
#
#     day_of_week_Tuesday  day_of_week_Wednesday  day_of_week_Thursday  \
# 0                     0                      0                     0
# 1                     0                      0                     0
# 9                     0                      0                     0
# 10                    0                      0                     0
# 14                    0                      0                     0
#
#     day_of_week_Friday  day_of_week_Saturday  day_of_week_Sunday  \
# 0                    1                     0                   0
# 1                    1                     0                   0
# 9                    0                     1                   0
# 10                   0                     1                   0
# 14                   0                     1                   0
#
#     CityRN_FOREIGN  CityRN_HOMELESS  CityRN_MIAMI
# 0                0                0             1
# 1                0                0             1
# 9                0                1             0
# 10               0                0             1
# 14               0                1             0
#
# [5 rows x 21 columns]

# %%
# df_combined.to_csv("Resources/df_combined_clean.csv",index=True,header=True)

# %%
df_group = df_combined.groupby('Booking_year_month').sum()

# %%
df_group.head()
# Out:
#                     Booking_month  DOB_month  Age<25  Age26-50  Age>50  \
# Booking_year_month
# 2015-05                        70        118       3         7       4
# 2015-06                       792        940      13        91      28
# 2015-07                       994        942      18        92      32
# 2015-08                      1224       1013      15       112      26
# 2015-09                      1089        803      11        84      26
#
#                     Summer  Spring  Winter  Autum  total_crime  \
# Booking_year_month
# 2015-05                  0      14       0      0           14
# 2015-06                  0     132       0      0          132
# 2015-07                142       0       0      0          142
# 2015-08                153       0       0      0          153
# 2015-09                121       0       0      0          121
#
#                     day_of_week_Monday  day_of_week_Tuesday  \
# Booking_year_month
# 2015-05                              0                    0
# 2015-06                             22                   13
# 2015-07                             14                   13
# 2015-08                             24                   17
# 2015-09                             13                   22
#
#                     day_of_week_Wednesday  day_of_week_Thursday  \
# Booking_year_month
# 2015-05                                 0                     0
# 2015-06                                23                    24
# 2015-07                                29                    28
# 2015-08                                20                    20
# 2015-09                                23                    24
#
#                     day_of_week_Friday  day_of_week_Saturday  \
# Booking_year_month
# 2015-05                              3                     4
# 2015-06                             19                    20
# 2015-07                             23                    21
# 2015-08                             18                    22
# 2015-09                             13                    10
#
#                     day_of_week_Sunday  CityRN_FOREIGN  CityRN_HOMELESS  \
# Booking_year_month
# 2015-05                              7               2                3
# 2015-06                             11               9               38
# 2015-07                             14              13               52
# 2015-08                             32              14               43
# 2015-09                             16              11               44
#
#                     CityRN_MIAMI
# Booking_year_month
# 2015-05                        9
# 2015-06                       85
# 2015-07                       77
# 2015-08                       96
# 2015-09                       66

# %%
df_group.to_csv("Resources/data2_transform_assault_group.csv",index=True,header=True)
